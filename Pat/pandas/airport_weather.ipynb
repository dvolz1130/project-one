# %% [markdown]
# ## Observations and Insights

# %%
# Observations and Insights

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
from scipy.stats import linregress
import numpy as np
import scipy.stats as st
import pandas as pd

# Study data files
airport_weather_path = "../data/LosAngeles2014-2019annual.csv"

# Read the mouse data and the study results
airport_weather = pd.read_csv(airport_weather_path)

# Combine the data into a single dataset
airport_weather_data_df = pd.DataFrame(airport_weather)

# Display the data table for preview
airport_weather_data_df.head(50)
# Out:
#        STATION                                      NAME  LATITUDE  LONGITUDE  \
# 0  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 1  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 2  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 3  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 4  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 5  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
#
#    ELEVATION  DATE  AWND  CDSD  CLDD  DP01  ...  HTDD   PRCP  SNOW  TAVG  \
# 0       29.6  2014   6.9  1125  1125    23  ...   809   8.30   NaN  66.0
# 1       29.6  2015   6.9  1183  1183    29  ...   872   5.96   NaN  65.6
# 2       29.6  2016   7.4   901   901    38  ...  1025  10.30   NaN  64.8
# 3       29.6  2017   7.4   994   994    36  ...  1079  12.28   NaN  65.1
# 4       29.6  2018   7.4  1019  1019    25  ...   843   7.80   NaN  65.2
# 5       29.6  2019   7.6   841   841    46  ...  1148  18.73   NaN  64.0
#
#    TMAX  TMIN  WDF2  WDF5  WSF2  WSF5
# 0  72.9  59.1   270   270  36.9  44.1
# 1  72.7  58.4   270   270  36.9  40.9
# 2  71.9  57.8   260   260  46.1  53.0
# 3  72.4  57.8   270   110  36.0  45.0
# 4  72.2  58.3   260   270  36.9  44.1
# 5  70.8  57.1   270   320  38.0  51.0
#
# [6 rows x 34 columns]

# %%
# Checking the number of mice.
airport_weather_data_days = airport_weather_data_df["DATE"].value_counts().count()
print(airport_weather_data_days)
# Out:
# 6

# %%
#airport_weather_data_df = airport_weather_data_df.rename(columns={"AWND" : "Average wind speed"})
airport_weather_data_df.head(50)
# Out:
#        STATION                                      NAME  LATITUDE  LONGITUDE  \
# 0  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 1  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 2  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 3  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 4  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 5  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
#
#    ELEVATION  DATE  AWND  CDSD  CLDD  DP01  ...  HTDD   PRCP  SNOW  TAVG  \
# 0       29.6  2014   6.9  1125  1125    23  ...   809   8.30   NaN  66.0
# 1       29.6  2015   6.9  1183  1183    29  ...   872   5.96   NaN  65.6
# 2       29.6  2016   7.4   901   901    38  ...  1025  10.30   NaN  64.8
# 3       29.6  2017   7.4   994   994    36  ...  1079  12.28   NaN  65.1
# 4       29.6  2018   7.4  1019  1019    25  ...   843   7.80   NaN  65.2
# 5       29.6  2019   7.6   841   841    46  ...  1148  18.73   NaN  64.0
#
#    TMAX  TMIN  WDF2  WDF5  WSF2  WSF5
# 0  72.9  59.1   270   270  36.9  44.1
# 1  72.7  58.4   270   270  36.9  40.9
# 2  71.9  57.8   260   260  46.1  53.0
# 3  72.4  57.8   270   110  36.0  45.0
# 4  72.2  58.3   260   270  36.9  44.1
# 5  70.8  57.1   270   320  38.0  51.0
#
# [6 rows x 34 columns]

# %%
airport_weather_data_df['DSND'] = airport_weather_data_df['DSND'].fillna(0)
airport_weather_data_df['DSNW'] = airport_weather_data_df['DSNW'].fillna(0)
airport_weather_data_df['EMSD'] = airport_weather_data_df['EMSD'].fillna(0)
airport_weather_data_df['EMSN'] = airport_weather_data_df['EMSN'].fillna(0)
airport_weather_data_df['SNOW'] = airport_weather_data_df['SNOW'].fillna(0)
#airport_weather_data_df['WT03'] = airport_weather_data_df['WT03'].fillna(0)
#airport_weather_data_df['WT04'] = airport_weather_data_df['WT04'].fillna(0)
#airport_weather_data_df['WT05'] = airport_weather_data_df['WT05'].fillna(0)
#airport_weather_data_df['WT06'] = airport_weather_data_df['WT06'].fillna(0)
#airport_weather_data_df['WT08'] = airport_weather_data_df['WT08'].fillna(0)
#airport_weather_data_df['WT09'] = airport_weather_data_df['WT09'].fillna(0)

airport_weather_data_df.head(50)
# Out:
#        STATION                                      NAME  LATITUDE  LONGITUDE  \
# 0  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 1  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 2  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 3  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 4  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 5  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
#
#    ELEVATION  DATE  AWND  CDSD  CLDD  DP01  ...  HTDD   PRCP  SNOW  TAVG  \
# 0       29.6  2014   6.9  1125  1125    23  ...   809   8.30   0.0  66.0
# 1       29.6  2015   6.9  1183  1183    29  ...   872   5.96   0.0  65.6
# 2       29.6  2016   7.4   901   901    38  ...  1025  10.30   0.0  64.8
# 3       29.6  2017   7.4   994   994    36  ...  1079  12.28   0.0  65.1
# 4       29.6  2018   7.4  1019  1019    25  ...   843   7.80   0.0  65.2
# 5       29.6  2019   7.6   841   841    46  ...  1148  18.73   0.0  64.0
#
#    TMAX  TMIN  WDF2  WDF5  WSF2  WSF5
# 0  72.9  59.1   270   270  36.9  44.1
# 1  72.7  58.4   270   270  36.9  40.9
# 2  71.9  57.8   260   260  46.1  53.0
# 3  72.4  57.8   270   110  36.0  45.0
# 4  72.2  58.3   260   270  36.9  44.1
# 5  70.8  57.1   270   320  38.0  51.0
#
# [6 rows x 34 columns]

# %%
for col in airport_weather_data_df.columns:
    print(col)
# Out:
# STATION
# NAME
# LATITUDE
# LONGITUDE
# ELEVATION
# DATE
# AWND
# CDSD
# CLDD
# DP01
# DP10
# DSND
# DSNW
# DT00
# DT32
# DX32
# DX70
# DX90
# EMNT
# EMSD
# EMSN
# EMXP
# EMXT
# HDSD
# HTDD
# PRCP
# SNOW
# TAVG
# TMAX
# TMIN
# WDF2
# WDF5
# WSF2
# WSF5

# %%
airport_weather_data_df = airport_weather_data_df.rename(columns={"AWND" : "Average wind speed",
                                                                  "CDSD" : "Cooling Degree Days (season-to-date)",
                                                                  "CLDD" : "Cooling Degree Days", 
                                                                  "DP01" : "Number of Days with >=0.01 inch", 
                                                                  "DP10" : "Number of Days with >=0.1 inch", 
                                                                  "DSND" : "Number of Days with Snow Depth >= 1 inch", 
                                                                  "DSNW" : "Number of Days with Snowfall >= 1 inch", 
                                                                  "DT00" : "Number of Days with Max Temp <= 0 degrees F", 
                                                                  "DT32" : "Number of Days with Max Temp <= 32 degrees F", 
                                                                  "DX32" : "Number of Days with Max Temp >= 32 degrees F",
                                                                  "DX70" : "Number of Days with Max temp >= 70 degrees F", 
                                                                  "DX90" : "Number of Days with Max temp >= 90 degrees F", 
                                                                  "EMNT" : "Extreme Minimum Temp", 
                                                                  "EMSD" : "Highest Daily Snow Depth", 
                                                                  "EMSN" : "Highest Daily Snowfall", 
                                                                  "EMXP" : "Highest Daily Precipitation", 
                                                                  "EMXT" : "Extreme Maximum Temp", 
                                                                  "HDSD" : "Heating Degree Days (season-to-date)",
                                                                  "HTDD" : "Heating Degree Days",
                                                                  "PRCP" : "Precipitation",
                                                                  "SNOW" : "Snowfall",
                                                                  "TAVG" : "Average Temperature",
                                                                  "TMAX" : "Maximum Temperature", 
                                                                  "TMIN" : "Minimum Temperature",
                                                                  "WDF2" : "Direction of fastest 2-minute wind",
                                                                  "WDF5" : "Direction of fastest 5-minute wind", 
                                                                  "WSF2" : "Fastest 2-minute wind",
                                                                  "WSF5" : "Fastest 5-minute wind"})
#                                                                  "WT01" : "Fog, ice fog, or freezing fog",
#                                                                  "WT02" : "Heavy fog or heaving freezing fog",
#                                                                  "WT03" : "Thunder",
#                                                                  "WT04" : "Ice pellets, sleet, snow pellets, or small hail",
#                                                                  "WT05" : "Hail (may include small hail)",
#                                                                  "WT06" : "Glaze or rime",
#                                                                  "WT08" : "Smoke or haze"})
#                                                                  "WT09" : "Blowing or drifting snow"})

# %%
airport_weather_data_df.head(50)
# Out:
#        STATION                                      NAME  LATITUDE  LONGITUDE  \
# 0  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 1  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 2  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 3  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 4  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
# 5  USW00023174  LOS ANGELES INTERNATIONAL AIRPORT, CA US    33.938  -118.3888
#
#    ELEVATION  DATE  Average wind speed  Cooling Degree Days (season-to-date)  \
# 0       29.6  2014                 6.9                                  1125
# 1       29.6  2015                 6.9                                  1183
# 2       29.6  2016                 7.4                                   901
# 3       29.6  2017                 7.4                                   994
# 4       29.6  2018                 7.4                                  1019
# 5       29.6  2019                 7.6                                   841
#
#    Cooling Degree Days  Number of Days with >=0.01 inch  ...  \
# 0                 1125                               23  ...
# 1                 1183                               29  ...
# 2                  901                               38  ...
# 3                  994                               36  ...
# 4                 1019                               25  ...
# 5                  841                               46  ...
#
#    Heating Degree Days  Precipitation  Snowfall  Average Temperature  \
# 0                  809           8.30       0.0                 66.0
# 1                  872           5.96       0.0                 65.6
# 2                 1025          10.30       0.0                 64.8
# 3                 1079          12.28       0.0                 65.1
# 4                  843           7.80       0.0                 65.2
# 5                 1148          18.73       0.0                 64.0
#
#    Maximum Temperature  Minimum Temperature  \
# 0                 72.9                 59.1
# 1                 72.7                 58.4
# 2                 71.9                 57.8
# 3                 72.4                 57.8
# 4                 72.2                 58.3
# 5                 70.8                 57.1
#
#    Direction of fastest 2-minute wind  Direction of fastest 5-minute wind  \
# 0                                 270                                 270
# 1                                 270                                 270
# 2                                 260                                 260
# 3                                 270                                 110
# 4                                 260                                 270
# 5                                 270                                 320
#
#    Fastest 2-minute wind  Fastest 5-minute wind
# 0                   36.9                   44.1
# 1                   36.9                   40.9
# 2                   46.1                   53.0
# 3                   36.0                   45.0
# 4                   36.9                   44.1
# 5                   38.0                   51.0
#
# [6 rows x 34 columns]

# %%
airport_weather_data_df.to_csv(r'../data/Cleansed Annual Weather Data LAX.csv', index = False)
